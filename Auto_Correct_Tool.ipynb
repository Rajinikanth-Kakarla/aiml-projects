# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <br>

# %% [markdown]
# #### 3 Different Libraries → 3 Different Solution
# - Gingerit → pip install gingerit
# - SpellChecker → pip install pyspellchecker
# - TextBlob → pip install textblob

# %% [markdown]
# ### Solution 1 using **GingerIt**

# %%
from gingerit.gingerit import GingerIt

# %%
parser = GingerIt()

# %%
def AutoCorrect(inp):
    result = parser.parse(inp)
    corrected = result['result']
    print(f"Input: {inp}")
    print(f"Corrected: {corrected}")
inp = input()
AutoCorrect(inp)
# Out:
# helo
# Input: helo
# Corrected: Hello

# %% [markdown]
# ### Solution 2 using **SpellChecker**

# %%
from spellchecker import SpellChecker

# %%
spell = SpellChecker()

# %%
def correct_word(word):
    corrected_word = spell.correction(word)
    return corrected_word

word = input()
corrected_word = correct_word(word)
print(f"Original word: {word}")
print(f"Corrected word: {corrected_word}")
# Out:
# comuter
# Original word: comuter
# Corrected word: computer

# %% [markdown]
# ### Solution 3 using TextBlob

# %%
from textblob import TextBlob

# %%
def TextblobCorrect(inpWord):
    b = TextBlob(inpWord)
    print(str(b.correct()))
inpWord = input()
TextblobCorrect(inp)
# Out:
# helo
# held

# %% [markdown]
# ### Why Solutions are different?
#
# - The reason why the outputs are different in the provided examples is because each approach uses a different algorithm or library for word correction.
#
# 1. The `AutoCorrect` function seems to be using a custom parser and correction mechanism, which might have its own rules and algorithms for correcting words. It produces the output "helo" corrected to "Hello".
#
# 2. The `correct_word` function utilizes the `spell.correction` method from the `pyspellchecker` library. This library applies spelling correction based on the frequency of words in a given corpus or dictionary. It produces the output "helo" corrected to "help".
#
# 3. The `TextblobCorrect` function relies on the `TextBlob` library, which offers various natural language processing functionalities. The `correct` method attempts to correct misspelled words using a combination of statistical analysis and language model techniques. In this case, "helo" is corrected to "held".
#
# - These differences in output occur because each library or algorithm uses its own set of rules, dictionaries, and statistical models to perform word correction.
